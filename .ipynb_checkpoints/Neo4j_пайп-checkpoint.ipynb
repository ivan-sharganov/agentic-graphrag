# %%
# стирание базы полное до нуля

# %%
# !docker stop neo4j_travel || true
# !docker rm neo4j_travel || true
# !docker volume rm neo4j_travel_data || true

# !docker run -d --name neo4j_travel \
  -p 7475:7474 -p 7688:7687 \
  -e NEO4J_AUTH=neo4j/12345678 \
  -v neo4j_travel_data:/data \
  neo4j:5

# !docker ps --filter name=neo4j_travel
# Out:
# neo4j_travel
# neo4j_travel
# neo4j_travel_data
# 15d492710178f230139300dc430bd7c477dd4654ea3ebfa9c8858c78237ac243

# %%
# вызов у дипсика промпта на извлечение триплетов и вывод = Cypher код внесения в БД

# %%
# # Jupyter cell: build prompt from files + call DeepSeek API + store Cypher + print finish_reason status

# import os
# import requests

# # ---- Files ----
# PROMPT_PATH = "prompt.txt"
# MSG_PATH = "message.txt"
# ONTO_PATH = "ontology.txt"

# # ---- DeepSeek API settings ----
# DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY", "sk-8da8031877dc4c39ae8d7b624c70f01f")
# if not DEEPSEEK_API_KEY:
#     raise RuntimeError("Set env var DEEPSEEK_API_KEY first.")

# DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL", "https://api.deepseek.com")
# MODEL = os.getenv("DEEPSEEK_MODEL", "deepseek-chat")

# # ---- Load templates & inputs ----
# with open(PROMPT_PATH, "r", encoding="utf-8") as f:
#     prompt_template = f.read()

# with open(MSG_PATH, "r", encoding="utf-8") as f:
#     message_text = f.read().strip()

# with open(ONTO_PATH, "r", encoding="utf-8") as f:
#     ontology_text = f.read().strip()

# # ---- Inject into prompt ----
# prompt = (
#     prompt_template
#     .replace("{RDF_ONTOLOGY_HERE}", ontology_text)
#     .replace("{TEXT_HERE}", message_text)
# )

# # ---- Call DeepSeek Chat Completions ----
# url = f"{DEEPSEEK_BASE_URL.rstrip('/')}/v1/chat/completions"
# headers = {
#     "Authorization": f"Bearer {DEEPSEEK_API_KEY}",
#     "Content-Type": "application/json",
# }

# payload = {
#     "model": MODEL,
#     "messages": [
#         {"role": "system", "content": "You are a precise assistant. Follow the user's prompt strictly."},
#         {"role": "user", "content": prompt},
#     ],
#     "temperature": 0.0,
# }

# resp = requests.post(url, headers=headers, json=payload, timeout=120)
# resp.raise_for_status()

# data = resp.json()

# choice = data["choices"][0]
# finish_reason = choice.get("finish_reason", "")
# answer = choice["message"]["content"]

# # Put generated Cypher into variable `cypher`


# # Print finish_reason with emoji
# # Common finish reasons: "stop" (normal), "length" (max tokens), sometimes others.
# emoji = "🟥" if finish_reason == "length" else "🟩"
# print(f"{emoji} finish_reason: {finish_reason}")

# # Print cypher
# print(answer)

# %%
# внести в бд

# %%
# from neo4j import GraphDatabase

# URI = "neo4j://localhost:7688"
# USER = "neo4j"
# PASSWORD = "12345678"
# DATABASE = "neo4j"

# def split_cypher(script: str):
#     # простая разбивка по ';' (для твоего случая достаточно)
#     parts = [p.strip() for p in script.split(";")]
#     return [p for p in parts if p]

# driver = GraphDatabase.driver(URI, auth=(USER, PASSWORD))

# try:
#     statements = split_cypher(answer)

#     with driver.session(database=DATABASE) as session:
#         for i, stmt in enumerate(statements, 1):
#             session.run(stmt).consume()
#             # print(f"OK {i}/{len(statements)}")  # раскомментируй если нужно логирование

#     print(f"✅ Executed {len(statements)} Cypher statements.")
# finally:
#     driver.close()
# Out:
# ✅ Executed 128 Cypher statements.

# %%
# сборка промпта и запрос к DeepSeek

# %%
import os
import json
import requests

PROMPT_PATH = "prompt.txt"
MSG_PATH = "message.txt"
ONTO_PATH = "ontology.txt"

DEEPSEEK_API_KEY = "sk-8da8031877dc4c39ae8d7b624c70f01f"
if not DEEPSEEK_API_KEY:
    raise RuntimeError("Set env var DEEPSEEK_API_KEY first (export DEEPSEEK_API_KEY=...).")

DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL", "https://api.deepseek.com").rstrip("/")
MODEL = os.getenv("DEEPSEEK_MODEL", "deepseek-chat")

with open(PROMPT_PATH, "r", encoding="utf-8") as f:
    prompt_template = f.read()

with open(MSG_PATH, "r", encoding="utf-8") as f:
    message_text = f.read().strip()

with open(ONTO_PATH, "r", encoding="utf-8") as f:
    ontology_text = f.read().strip()

prompt = (prompt_template
          .replace("{RDF_ONTOLOGY_HERE}", ontology_text)
          .replace("{TEXT_HERE}", message_text))

url = f"{DEEPSEEK_BASE_URL}/v1/chat/completions"
headers = {
    "Authorization": f"Bearer {DEEPSEEK_API_KEY}",
    "Content-Type": "application/json",
}
payload = {
    "model": MODEL,
    "messages": [
        {"role": "system", "content": "Return ONLY JSON. No markdown. Follow the template strictly."},
        {"role": "user", "content": prompt},
    ],
    "temperature": 0.0,
}

resp = requests.post(url, headers=headers, json=payload, timeout=180)
resp.raise_for_status()
data = resp.json()

# DeepSeek API finish reason (transport-level)
api_finish = data["choices"][0].get("finish_reason", "")
content = data["choices"][0]["message"]["content"]

# Save to variable for next cells
answer = content

emoji = "🟢" if api_finish != "length" else "🔴"
print(f"{emoji} API finish_reason = {api_finish}")
print(answer)  # preview
# Out:
# 🟢 API finish_reason = stop
# {
#   "payload": {
#     "ontology_version": "https://example.org/pcfr#",
#     "nodes": [
#       {
#         "label": "Encounter",
#         "key": "encounter_1",
#         "properties": {
#           "sourcePostID": 1,
#           "encounterDurationMin": 5
#         }
#       },
#       {
#         "label": "Traveller",
#         "key": "traveller_1"
#       },
#       {
#         "label": "Traveller",
#         "key": "traveller_2"
#       },
#       {
#         "label": "BorderOfficer",
#         "key": "officer_1"
#       },
#       {
#         "label": "DocumentCheck",
#         "key": "doccheck_1"
#       },
#       {
#         "label": "Questioning",
#         "key": "questioning_1"
#       },
#       {
#         "label": "Stamping",
#         "key": "stamping_1"
#       },
#       {
#         "label": "Outcome",
#         "key": "outcome_1",
#         "properties": {
#           "resultCode": "stamped"
#         }
#       },
#       {
# ...

# %%
# Ячейка — JSON → Cypher генерация

# %%
import json
import re

def strip_code_fences(s: str) -> str:
    s = s.strip()
    # remove ```json ... ``` or ``` ... ```
    if s.startswith("```"):
        s = re.sub(r"^```(?:json)?\s*", "", s)
        s = re.sub(r"\s*```$", "", s)
    return s.strip()

def cypher_literal(v):
    if v is None:
        return "null"
    if isinstance(v, bool):
        return "true" if v else "false"
    if isinstance(v, (int, float)):
        # keep numeric unquoted
        return str(v)
    s = str(v).replace("\\", "\\\\").replace("'", "\\'")
    return f"'{s}'"

def gen_constraints(nodes):
    labels = sorted({n["label"] for n in nodes})
    return [f"CREATE CONSTRAINT IF NOT EXISTS FOR (n:{label}) REQUIRE n.key IS UNIQUE"
            for label in labels]

def gen_node_stmt(node):
    label = node["label"]
    key = node["key"]
    props = node.get("properties", {}) or {}

    set_parts = [f"n.{k}={cypher_literal(v)}" for k, v in props.items()]
    set_clause = (" SET " + ", ".join(set_parts)) if set_parts else ""
    return f"MERGE (n:{label} {{key:{cypher_literal(key)}}}){set_clause}"

def gen_rel_stmt(rel):
    fl = rel["from"]["label"]; fk = rel["from"]["key"]
    tl = rel["to"]["label"];   tk = rel["to"]["key"]
    rt = rel["type"]

    # self-contained: MATCH by key inside the statement
    return (
        f"MATCH (a:{fl} {{key:{cypher_literal(fk)}}}), (b:{tl} {{key:{cypher_literal(tk)}}}) "
        f"MERGE (a)-[:{rt}]->(b)"
    )

# Parse model output JSON
raw = strip_code_fences(answer)
root = json.loads(raw)

abox = root["payload"]
nodes = abox.get("nodes", [])
rels = abox.get("relationships", [])

# Build statements
cypher_statements = []
cypher_statements += gen_constraints(nodes)
cypher_statements += [gen_node_stmt(n) for n in nodes]
cypher_statements += [gen_rel_stmt(r) for r in rels]

print("LLM finish_reason:", root.get("finish_reason"))
print("LLM reason:", root.get("reason"))
print(f"Prepared {len(cypher_statements)} Cypher statements "
      f"({len(nodes)} nodes, {len(rels)} rels).")

# Optional preview
print("\n--- First 10 statements ---")
for s in cypher_statements[:10]:
    print(s + ";")
# Out:
# LLM finish_reason: 🟢 complete
# LLM reason: Successfully extracted all entities and relationships from the text.
# Prepared 80 Cypher statements (26 nodes, 29 rels).
#
# --- First 10 statements ---
# CREATE CONSTRAINT IF NOT EXISTS FOR (n:Airport) REQUIRE n.key IS UNIQUE;
# CREATE CONSTRAINT IF NOT EXISTS FOR (n:BorderOfficer) REQUIRE n.key IS UNIQUE;
# CREATE CONSTRAINT IF NOT EXISTS FOR (n:Cash) REQUIRE n.key IS UNIQUE;
# CREATE CONSTRAINT IF NOT EXISTS FOR (n:CashAmount) REQUIRE n.key IS UNIQUE;
# CREATE CONSTRAINT IF NOT EXISTS FOR (n:City) REQUIRE n.key IS UNIQUE;
# CREATE CONSTRAINT IF NOT EXISTS FOR (n:Country) REQUIRE n.key IS UNIQUE;
# CREATE CONSTRAINT IF NOT EXISTS FOR (n:DocumentCheck) REQUIRE n.key IS UNIQUE;
# CREATE CONSTRAINT IF NOT EXISTS FOR (n:Employment) REQUIRE n.key IS UNIQUE;
# CREATE CONSTRAINT IF NOT EXISTS FOR (n:Encounter) REQUIRE n.key IS UNIQUE;
# CREATE CONSTRAINT IF NOT EXISTS FOR (n:HotelBookingDoc) REQUIRE n.key IS UNIQUE;

# %%
# исполнение Cypher (каждая строка автономна)

# %%
from neo4j import GraphDatabase

URI = "neo4j://localhost:7688"
USER = "neo4j"
PASSWORD = "12345678"
DATABASE = "neo4j"

driver = GraphDatabase.driver(URI, auth=(USER, PASSWORD))

try:
    with driver.session(database=DATABASE) as session:
        for i, stmt in enumerate(cypher_statements, 1):
            session.run(stmt).consume()
    print(f"✅ Executed {len(cypher_statements)} statements.")
finally:
    driver.close()
# Out:
# ✅ Executed 80 statements.
