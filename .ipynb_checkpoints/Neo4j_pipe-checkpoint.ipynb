# %% [markdown]
# # Содержание
# ### Строим граф для 1 сбщ
# 1. Стереть Neo4j базу до нуля (7688)
# 2. Вызов DeepSeek с промптом (cклеиваем строки в промпт (+ сбщ, + онто))
# 3. Валидация и исправление ABox JSON c помощью LLM
# 4. JSON -> Cypher конвертер (LLM возвращает JSON с узлами и нодами, чтобы в конт окно влезало. Cypher не влезал!)
# 5. Запись в файл cypher_checkpoints - слепки базы на каждое сбщ
# 6. Внесение инфы в базу (исполнение всех Cypher команд по очереди)

# %%
# 1 стирание базы полное до нуля

# %%
def step_1_reset_db():
    # !docker stop neo4j_travel || true
    # !docker rm neo4j_travel || true
    # !docker volume rm neo4j_travel_data || true
    
    # !docker run -d --name neo4j_travel \
      -p 7475:7474 -p 7688:7687 \
      -e NEO4J_AUTH=neo4j/12345678 \
      -v neo4j_travel_data:/data \
      neo4j:5
    
    # !docker ps --filter name=neo4j_travel   
    print("Did reset DB")
    return None

# %%
# 2 сборка промпта и запрос к DeepSeek - выход ABox в виде JSON

# %%
def step_2_prompt_to_abox(msg_as_JSON) -> str:
    import os
    import json
    import requests
    import time

    PROMPT_PATH = "prompt.txt"
    ONTO_PATH = "ontology.txt"

    DEEPSEEK_API_KEY = "sk-8da8031877dc4c39ae8d7b624c70f01f"
    if not DEEPSEEK_API_KEY:
        raise RuntimeError("Set env var DEEPSEEK_API_KEY (export DEEPSEEK_API_KEY=...).")

    DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL", "https://api.deepseek.com").rstrip("/")
    MODEL = os.getenv("DEEPSEEK_MODEL", "deepseek-reasoner")  # or deepseek-chat

    # --- load prompt template + ontology ---
    with open(PROMPT_PATH, "r", encoding="utf-8") as f:
        prompt_template = f.read()

    with open(ONTO_PATH, "r", encoding="utf-8") as f:
        ontology_text = f.read().strip()

    # --- normalize message JSON string ---
    if isinstance(msg_as_JSON, (dict, list)):
        message_json_string = json.dumps(msg_as_JSON, ensure_ascii=False)
    else:
        message_json_string = str(msg_as_JSON).strip()

    # validate that it's JSON (LLM expects JSON string with keys post_id/post_url/author/date/text)
    try:
        json.loads(message_json_string)
    except Exception as e:
        raise ValueError(f"msg_as_JSON must be a valid JSON string (or dict). Parse error: {e}") from e

    # --- stitch prompt ---
    prompt = (
        prompt_template
        .replace("{RDF_ONTOLOGY_HERE}", ontology_text)
        .replace("{MESSAGE_JSON_STRING_HERE}", message_json_string)
    )

    # sanity check for unresolved placeholders
    unresolved = [p for p in ["{RDF_ONTOLOGY_HERE}", "{MESSAGE_JSON_STRING_HERE}"] if p in prompt]
    if unresolved:
        raise RuntimeError(f"Unresolved placeholders in prompt: {unresolved}")

    # --- call DeepSeek ---
    url = f"{DEEPSEEK_BASE_URL}/v1/chat/completions"
    headers = {
        "Authorization": f"Bearer {DEEPSEEK_API_KEY}",
        "Content-Type": "application/json",
    }
    payload = {
        "model": MODEL,
        "messages": [
            # system можно оставить очень коротким, промпт уже строгий
            {"role": "system", "content": "Return ONLY valid JSON object. No markdown. No code fences."},
            {"role": "user", "content": prompt},
        ],
        "temperature": 0.0,
    }

    t0 = time.perf_counter()
    resp = requests.post(url, headers=headers, json=payload, timeout=180)
    elapsed = time.perf_counter() - t0
    print(f"DeepSeek API latency: {elapsed:.2f}s")
    resp.raise_for_status()
    data = resp.json()

    api_finish = data["choices"][0].get("finish_reason", "")
    content = data["choices"][0]["message"]["content"]

    emoji = "🟢" if api_finish != "length" else "🔴"
    print(f"{emoji} API finish_reason = {api_finish}")

    # optional: validate JSON (hard fail if model returned junk)
    try:
        json.loads(content)
    except Exception as e:
        raise ValueError(f"Model did not return valid JSON. Error: {e}\nRaw content:\n{content[:2000]}") from e

    print(content)  # preview
    return content

# %%
# print(answer)  # preview
# print(prompt)

# %%
# 3 Валидация ABox JSON перед генерацией Cypher

# %%
def step_3_validate_abox():
    
    # import json
    # import re
    
    # def _strip_code_fences(s: str) -> str:
    #     s = s.strip()
    #     if s.startswith("```"):
    #         s = re.sub(r"^```(?:json)?\s*", "", s)
    #         s = re.sub(r"\s*```$", "", s)
    #     return s.strip()
    
    # def _one_line(s: str) -> str:
    #     return " ".join(str(s).split())
    
    # raw_answer = _strip_code_fences(answer)
    # try:
    #     abox_obj = json.loads(raw_answer)
    #     abox_json = json.dumps(abox_obj, ensure_ascii=False, separators=(",", ":"))
    # except Exception:
    #     abox_json = _one_line(raw_answer)
    
    # message = message_text
    # ontology = ontology_text
    
    # PROMPT_VALID_PATH = "prompt_extr_valid.txt"
    # with open(PROMPT_VALID_PATH, "r", encoding="utf-8") as f:
    #     prompt_template_valid = f.read()
    
    # prompt_validation = (prompt_template_valid
    #     .replace("{MESSAGE}", _one_line(message))
    #     .replace("{ONTOLOGY}", _one_line(ontology))
    #     .replace("{ABOX_JSON}", abox_json)
    # )
    
    
    # payload_valid = {
    #     "model": MODEL,
    #     "messages": [
    #         {"role": "system", "content": "Return ONLY JSON. No markdown. Output must be a valid ABox JSON and nothing else."},
    #         {"role": "user", "content": prompt_validation},
    #     ],
    #     "temperature": 0.0,
    # }
    
    # resp_valid = requests.post(url, headers=headers, json=payload_valid, timeout=180)
    # resp_valid.raise_for_status()
    # data_valid = resp_valid.json()
    # api_finish_valid = data_valid["choices"][0].get("finish_reason", "")
    # content_valid = data_valid["choices"][0]["message"]["content"]
    
    # answer_raw = answer
    # answer = content_valid
    
    # emoji = "🟢" if api_finish_valid != "length" else "🔴"
    # print(f"{emoji} API finish_reason = {api_finish_valid}")
    # print(answer)
    return None

# %%
# 4 JSON → Cypher генерация

# %%
def step_4_abox_to_cypher(LLM_answer: str) -> List[str]:
    import json
    import re
    from pathlib import Path

    # =========================
    # Helpers
    # =========================

    def strip_code_fences(s: str) -> str:
        s = (s or "").strip()
        if s.startswith("```"):
            s = re.sub(r"^```(?:json)?\s*", "", s)
            s = re.sub(r"\s*```$", "", s)
        return s.strip()

    def neo4j_local_name(name: str) -> str:
        if not name:
            return ""
        if ":" in name:
            return name.split(":")[-1]
        if "#" in name:
            return name.split("#")[-1]
        if "/" in name:
            return name.rsplit("/", 1)[-1]
        return name

    def neo4j_safe_ident(name: str) -> str:
        n = neo4j_local_name(name)
        n = re.sub(r"[^A-Za-z0-9_]", "_", n)
        if not n:
            return "X"
        if n[0].isdigit():
            n = "_" + n
        return n

    def cypher_literal(v, prop_name=None):
        if v is None:
            return "null"
        if isinstance(v, bool):
            return "true" if v else "false"
        if isinstance(v, (int, float)):
            return str(v)

        # Special handling for ISO date → Neo4j localdatetime()
        if prop_name == "postDateISO":
            return f"localdatetime('{v}')"

        s = str(v)
        s = s.replace("\\", "\\\\").replace("'", "\\'")
        s = s.replace("\n", "\\n").replace("\r", "\\r")
        return f"'{s}'"

    def contains_cyrillic(s):
        return bool(re.search(r"[А-Яа-яЁё]", s))

    # =========================
    # Parse JSON from LLM
    # =========================

    # global answer  # must exist
    answer = LLM_answer
    raw = strip_code_fences(answer)
    root = json.loads(raw)

    payload = root.get("payload", {}) or {}
    nodes = payload.get("nodes", []) or []
    rels = payload.get("relationships", []) or []

    cypher_statements = []

    # =========================
    # Constraints
    # =========================

    labels = sorted({
        neo4j_safe_ident(n.get("label", ""))
        for n in nodes
        if n.get("label")
    })

    for label in labels:
        cypher_statements.append(
            f"CREATE CONSTRAINT IF NOT EXISTS FOR (n:{label}) REQUIRE n.key IS UNIQUE"
        )

    # =========================
    # Nodes
    # =========================

    for node in nodes:
        label_raw = node.get("label", "")
        key = node.get("key")

        if not label_raw or key is None:
            continue

        label = neo4j_safe_ident(label_raw)
        props = node.get("properties", {}) or {}

        set_parts = []

        for k, v in props.items():
            prop_key = neo4j_safe_ident(k)

            if isinstance(v, str) and contains_cyrillic(v):
                print(f"⚠ WARNING: Cyrillic detected in property '{prop_key}' → '{v}'")

            set_parts.append(f"n.{prop_key}={cypher_literal(v, prop_key)}")

        set_clause = (" SET " + ", ".join(set_parts)) if set_parts else ""

        stmt = f"MERGE (n:{label} {{key:{cypher_literal(key)}}}){set_clause}"
        cypher_statements.append(stmt)

    # =========================
    # Relationships
    # =========================

    for rel in rels:
        f = rel.get("from", {}) or {}
        t = rel.get("to", {}) or {}

        fl_raw = f.get("label", "")
        fk = f.get("key")
        tl_raw = t.get("label", "")
        tk = t.get("key")
        rt_raw = rel.get("type", "")

        if not fl_raw or not tl_raw or not rt_raw or fk is None or tk is None:
            continue

        fl = neo4j_safe_ident(fl_raw)
        tl = neo4j_safe_ident(tl_raw)
        rt = neo4j_safe_ident(rt_raw)

        stmt = (
            f"MATCH (a:{fl} {{key:{cypher_literal(fk)}}}), "
            f"(b:{tl} {{key:{cypher_literal(tk)}}}) "
            f"MERGE (a)-[:{rt}]->(b)"
        )

        cypher_statements.append(stmt)

    # =========================
    # Output
    # =========================

    print("LLM finish_reason:", root.get("finish_reason"))
    print("LLM reason:", root.get("reason"))
    print(f"Prepared {len(cypher_statements)} Cypher statements.\n")
    # cypher_statements = abox_json_to_cypher(answer)
    # for s in cypher_statements[:15]:
    #     print(s + ";")
    return cypher_statements

# %%
# 5 Сохранение Cypher в чекпоинт

# %%
def step_5_save_cypher(cypher_statements: List[str]):
    import os
    import re
    
    ckpt_dir = "cypher_checkpoints"
    os.makedirs(ckpt_dir, exist_ok=True)
    
    existing = []
    for name in os.listdir(ckpt_dir):
        m = re.match(r"^cypher_(\d+)\.txt$", name)
        if m:
            existing.append(int(m.group(1)))
    
    next_num = max(existing, default=0) + 1
    out_path = os.path.join(ckpt_dir, f"cypher_{next_num}.txt")
    
    with open(out_path, "w", encoding="utf-8") as f:
        for stmt in cypher_statements:
            f.write(stmt)
            f.write(";")
    
    print(f"Saved {len(cypher_statements)} statements to {out_path}")
    return None

# %%
# print(cypher_statements)

# %%
# 6 исполнение Cypher (каждая строка автономна)

# %%
def step_6_execute_cypher(cypher_statements: List[str]):
    from neo4j import GraphDatabase
    
    URI = "neo4j://localhost:7688"
    USER = "neo4j"
    PASSWORD = "12345678"
    DATABASE = "neo4j"
    
    driver = GraphDatabase.driver(URI, auth=(USER, PASSWORD))
    
    try:
        with driver.session(database=DATABASE) as session:
            for i, stmt in enumerate(cypher_statements, 1):
                session.run(stmt).consume()
        print(f"✅ Executed {len(cypher_statements)} statements.")
    finally:
        driver.close()    
    return None

# %%
# 7 запуск пайплайна

# %%
# step_1_reset_db()

import json

with open("messages.json", "r", encoding="utf-8") as f:
    messages = json.load(f)
messages = list(map(lambda x: json.dumps(x, ensure_ascii=False), messages[2:]))


for msg in messages:
    print(msg)
    answer = step_2_prompt_to_abox(msg) 
    # step_3_validate_abox()
    cypher_statements = step_4_abox_to_cypher(answer)
    step_5_save_cypher(cypher_statements)
    step_6_execute_cypher(cypher_statements)

subprocess.run(["afplay", "/System/Library/Sounds/Blow.aiff"], check=False)
# Out:
# {"post_id": 9752768, "post_url": "https://forum.awd.ru/viewtopic.php?p=9752768#p9752768", "author": "Twiggi", "date": "10 дек 2019, 06:40", "text": "В прошлом году у мужа спросили (в аэропорту Лиона), где он собирается жить. Показал брони жилья. У меня не спрашивали.В этом году (Ницца) - ничего не спрашивали."}
# DeepSeek API latency: 109.97s
# 🟢 API finish_reason = stop
# {
#   "payload": {
#     "ontology_version": "pcfr-v3",
#     "nodes": [
#       {
#         "label": "City",
#         "key": "city_lyon",
#         "properties": {
#           "entityName": "Lyon"
#         }
#       },
#       {
#         "label": "City",
#         "key": "city_nice",
#         "properties": {
#           "entityName": "Nice"
#         }
#       },
#       {
#         "label": "Airport",
#         "key": "airport_lys",
#         "properties": {
#           "entityName": "Lyon Airport"
#         }
#       },
#       {
#         "label": "Airport",
#         "key": "airport_nce",
#         "properties": {
#           "entityName": "Nice Airport"
#         }
#       },
#       {
#         "label": "Country",
#         "key": "country_france",
#         "properties": {
#           "entityName": "France"
#         }
#       },
#       {
#         "label": "Traveller",
#         "key": "traveller_author",
#         "properties": {
#           "entityName": "Twiggi"
#         }
#       },
#       {
#         "label": "Traveller",
#         "key": "traveller_husband",
#         "properties": {
#           "entityName": "Husband"
#         }
#       },
#       {
#         "label": "HotelBookingDoc",
#         "key": "doctype_hotelbooking",
#         "properties": {}
#       },
#       {
#         "label": "VisitPurpose",
#         "key": "topic_visitpurpose",
#         "properties": {}
#       },
#       {
#         "label": "Encounter",
#         "key": "encounter_9752768_husband",
#         "properties": {
#           "sourcePostID": 9752768,
#           "sourcePostURL": "https://forum.awd.ru/viewtopic.php?p=9752768#p9752768",
#           "sourcePostAuthor": "Twiggi",
#           "sourcePostDateTime": "2019-12-10T06:40:00"
#         }
#       },
#       {
#         "label": "Encounter",
#         "key": "encounter_9752768_author",
#         "properties": {
#           "sourcePostID": 9752768,
#           "sourcePostURL": "https://forum.awd.ru/viewtopic.php?p=9752768#p9752768",
#           "sourcePostAuthor": "Twiggi",
#           "sourcePostDateTime": "2019-12-10T06:40:00"
#         }
#       },
#       {
#         "label": "DocumentCheck",
#         "key": "doccheck_encounter_9752768_husband_hotelbooking",
#         "properties": {
#           "presented": true
#         }
#       },
#       {
#         "label": "Questioning",
#         "key": "questioning_encounter_9752768_husband",
#         "properties": {
#           "wasAsked": true,
#           "topic": "where he is going to live"
#         }
#       }
#     ],
#     "relationships": [
#       {
#         "from": {"label": "Airport", "key": "airport_lys"},
#         "type": "locatedInCity",
#         "to": {"label": "City", "key": "city_lyon"}
#       },
#       {
#         "from": {"label": "Airport", "key": "airport_nce"},
#         "type": "locatedInCity",
#         "to": {"label": "City", "key": "city_nice"}
#       },
#       {
#         "from": {"label": "City", "key": "city_lyon"},
#         "type": "locatedInCountry",
#         "to": {"label": "Country", "key": "country_france"}
#       },
#       {
#         "from": {"label": "City", "key": "city_nice"},
#         "type": "locatedInCountry",
#         "to": {"label": "Country", "key": "country_france"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_9752768_husband"},
#         "type": "hasTraveler",
#         "to": {"label": "Traveller", "key": "traveller_husband"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_9752768_husband"},
#         "type": "atAirport",
#         "to": {"label": "Airport", "key": "airport_lys"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_9752768_husband"},
#         "type": "atCity",
#         "to": {"label": "City", "key": "city_lyon"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_9752768_husband"},
#         "type": "atCountry",
#         "to": {"label": "Country", "key": "country_france"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_9752768_husband"},
#         "type": "hasDocumentCheck",
#         "to": {"label": "DocumentCheck", "key": "doccheck_encounter_9752768_husband_hotelbooking"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_9752768_husband"},
#         "type": "hasQuestioning",
#         "to": {"label": "Questioning", "key": "questioning_encounter_9752768_husband"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_9752768_husband_hotelbooking"},
#         "type": "requestedDocType",
#         "to": {"label": "HotelBookingDoc", "key": "doctype_hotelbooking"}
#       },
#       {
#         "from": {"label": "Questioning", "key": "questioning_encounter_9752768_husband"},
#         "type": "questionTopic",
#         "to": {"label": "VisitPurpose", "key": "topic_visitpurpose"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_9752768_author"},
#         "type": "hasTraveler",
#         "to": {"label": "Traveller", "key": "traveller_author"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_9752768_author"},
#         "type": "atAirport",
#         "to": {"label": "Airport", "key": "airport_nce"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_9752768_author"},
#         "type": "atCity",
#         "to": {"label": "City", "key": "city_nice"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_9752768_author"},
#         "type": "atCountry",
#         "to": {"label": "Country", "key": "country_france"}
#       }
#     ]
#   },
#   "finish_reason": "🟢 complete",
#   "reason": "All described encounters and entities extracted from text.",
#   "warnings": ["Assumed IATA codes LYS for Lyon and NCE for Nice as not specified in text."]
# }
# LLM finish_reason: 🟢 complete
# LLM reason: All described encounters and entities extracted from text.
# Prepared 38 Cypher statements.
#
# Saved 38 statements to cypher_checkpoints/cypher_3.txt
# ✅ Executed 38 statements.
# {"post_id": 11165134, "post_url": "https://forum.awd.ru/viewtopic.php?p=11165134#p11165134", "author": "НатальяF", "date": "20 сен 2022, 18:55", "text": "Отпишусь в этой теме по своему вопросу: на французской границе у меня спросили только обратный билет. Брала на всякий случай и приглашение, и нал - не пригодилось:)"}
# DeepSeek API latency: 21.07s
# 🟢 API finish_reason = stop
# {
#   "payload": {
#     "ontology_version": "pcfr v3",
#     "nodes": [
#       {
#         "label": "Country",
#         "key": "country_france",
#         "properties": {
#           "entityName": "France"
#         }
#       },
#       {
#         "label": "Traveller",
#         "key": "traveller_natalyaf",
#         "properties": {
#           "entityName": "NatalyaF"
#         }
#       },
#       {
#         "label": "Encounter",
#         "key": "encounter_11165134_natalyaf",
#         "properties": {
#           "sourcePostID": 11165134,
#           "sourcePostURL": "https://forum.awd.ru/viewtopic.php?p=11165134#p11165134",
#           "sourcePostAuthor": "NatalyaF",
#           "sourcePostDateTime": "2022-09-20T18:55:00"
#         }
#       },
#       {
#         "label": "FirstPersonExperience",
#         "key": "firstpersonexperience",
#         "properties": {}
#       },
#       {
#         "label": "Experienced",
#         "key": "experienced",
#         "properties": {}
#       },
#       {
#         "label": "DocumentCheck",
#         "key": "doccheck_encounter_11165134_natalyaf_returnticket",
#         "properties": {
#           "presented": true
#         }
#       },
#       {
#         "label": "ReturnTicket",
#         "key": "returnticket",
#         "properties": {}
#       },
#       {
#         "label": "VerbalInquiryOnly",
#         "key": "verbalinquiryonly",
#         "properties": {}
#       }
#     ],
#     "relationships": [
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11165134_natalyaf"
#         },
#         "type": "hasTraveler",
#         "to": {
#           "label": "Traveller",
#           "key": "traveller_natalyaf"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11165134_natalyaf"
#         },
#         "type": "atCountry",
#         "to": {
#           "label": "Country",
#           "key": "country_france"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11165134_natalyaf"
#         },
#         "type": "assertionKind",
#         "to": {
#           "label": "FirstPersonExperience",
#           "key": "firstpersonexperience"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11165134_natalyaf"
#         },
#         "type": "evidentiality",
#         "to": {
#           "label": "Experienced",
#           "key": "experienced"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11165134_natalyaf"
#         },
#         "type": "hasDocumentCheck",
#         "to": {
#           "label": "DocumentCheck",
#           "key": "doccheck_encounter_11165134_natalyaf_returnticket"
#         }
#       },
#       {
#         "from": {
#           "label": "DocumentCheck",
#           "key": "doccheck_encounter_11165134_natalyaf_returnticket"
#         },
#         "type": "requestedDocType",
#         "to": {
#           "label": "ReturnTicket",
#           "key": "returnticket"
#         }
#       },
#       {
#         "from": {
#           "label": "DocumentCheck",
#           "key": "doccheck_encounter_11165134_natalyaf_returnticket"
#         },
#         "type": "checkMode",
#         "to": {
#           "label": "VerbalInquiryOnly",
#           "key": "verbalinquiryonly"
#         }
#       }
#     ]
#   },
#   "finish_reason": "🟢 complete",
#   "reason": "All relevant facts from the text extracted.",
#   "warnings": []
# }
# LLM finish_reason: 🟢 complete
# LLM reason: All relevant facts from the text extracted.
# Prepared 23 Cypher statements.
#
# Saved 23 statements to cypher_checkpoints/cypher_4.txt
# ✅ Executed 23 statements.
# {"post_id": 3898899, "post_url": "https://forum.awd.ru/viewtopic.php?p=3898899#p3898899", "author": "goa-200", "date": "10 июн 2013, 08:38", "text": "В Марселе потребовали показать обратный билет! Хорошо он был в ручной клади, чемоданы-то отдают ПОСЛЕ пограничника. Так что возите при себе  распечатку билета обратного."}
# DeepSeek API latency: 103.61s
# 🟢 API finish_reason = stop
# {
#   "payload": {
#     "ontology_version": "pcfr_v3",
#     "nodes": [
#       {
#         "label": "City",
#         "key": "city_marseille",
#         "properties": {
#           "entityName": "Marseille"
#         }
#       },
#       {
#         "label": "Traveller",
#         "key": "traveller_author",
#         "properties": {
#           "entityName": "goa-200"
#         }
#       },
#       {
#         "label": "BorderOfficer",
#         "key": "officer_marseille",
#         "properties": {
#           "entityName": "Border officer"
#         }
#       },
#       {
#         "label": "Encounter",
#         "key": "encounter_3898899_author",
#         "properties": {
#           "sourcePostID": 3898899,
#           "sourcePostURL": "https://forum.awd.ru/viewtopic.php?p=3898899#p3898899",
#           "sourcePostAuthor": "goa-200",
#           "sourcePostDateTime": "2013-06-10T08:38:00"
#         }
#       },
#       {
#         "label": "DocumentCheck",
#         "key": "doccheck_encounter_3898899_author_return_ticket",
#         "properties": {
#           "presented": true
#         }
#       },
#       {
#         "label": "ReturnTicket",
#         "key": "returnticket"
#       },
#       {
#         "label": "Printout",
#         "key": "printout"
#       },
#       {
#         "label": "FirstPersonExperience",
#         "key": "firstpersonexperience"
#       },
#       {
#         "label": "Experienced",
#         "key": "experienced"
#       },
#       {
#         "label": "Claim",
#         "key": "claim_3898899_carry_printout",
#         "properties": {
#           "claimText": "Carry with you a printout of the return ticket.",
#           "sourcePostID": 3898899,
#           "sourcePostURL": "https://forum.awd.ru/viewtopic.php?p=3898899#p3898899",
#           "sourcePostAuthor": "goa-200",
#           "sourcePostDateTime": "2013-06-10T08:38:00"
#         }
#       },
#       {
#         "label": "Advice",
#         "key": "advice"
#       },
#       {
#         "label": "UniversalScope",
#         "key": "universalscope"
#       },
#       {
#         "label": "DocumentScrutiny",
#         "key": "documentscrutiny"
#       }
#     ],
#     "relationships": [
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_3898899_author"
#         },
#         "type": "hasTraveler",
#         "to": {
#           "label": "Traveller",
#           "key": "traveller_author"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_3898899_author"
#         },
#         "type": "hasOfficer",
#         "to": {
#           "label": "BorderOfficer",
#           "key": "officer_marseille"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_3898899_author"
#         },
#         "type": "hasDocumentCheck",
#         "to": {
#           "label": "DocumentCheck",
#           "key": "doccheck_encounter_3898899_author_return_ticket"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_3898899_author"
#         },
#         "type": "atCity",
#         "to": {
#           "label": "City",
#           "key": "city_marseille"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_3898899_author"
#         },
#         "type": "assertionKind",
#         "to": {
#           "label": "FirstPersonExperience",
#           "key": "firstpersonexperience"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_3898899_author"
#         },
#         "type": "evidentiality",
#         "to": {
#           "label": "Experienced",
#           "key": "experienced"
#         }
#       },
#       {
#         "from": {
#           "label": "DocumentCheck",
#           "key": "doccheck_encounter_3898899_author_return_ticket"
#         },
#         "type": "requestedDocType",
#         "to": {
#           "label": "ReturnTicket",
#           "key": "returnticket"
#         }
#       },
#       {
#         "from": {
#           "label": "DocumentCheck",
#           "key": "doccheck_encounter_3898899_author_return_ticket"
#         },
#         "type": "presentedFormat",
#         "to": {
#           "label": "Printout",
#           "key": "printout"
#         }
#       },
#       {
#         "from": {
#           "label": "DocumentCheck",
#           "key": "doccheck_encounter_3898899_author_return_ticket"
#         },
#         "type": "checkedBy",
#         "to": {
#           "label": "BorderOfficer",
#           "key": "officer_marseille"
#         }
#       },
#       {
#         "from": {
#           "label": "Claim",
#           "key": "claim_3898899_carry_printout"
#         },
#         "type": "assertionKind",
#         "to": {
#           "label": "Advice",
#           "key": "advice"
#         }
#       },
#       {
#         "from": {
#           "label": "Claim",
#           "key": "claim_3898899_carry_printout"
#         },
#         "type": "evidentiality",
#         "to": {
#           "label": "Experienced",
#           "key": "experienced"
#         }
#       },
#       {
#         "from": {
#           "label": "Claim",
#           "key": "claim_3898899_carry_printout"
#         },
#         "type": "claimScope",
#         "to": {
#           "label": "UniversalScope",
#           "key": "universalscope"
#         }
#       },
#       {
#         "from": {
#           "label": "Claim",
#           "key": "claim_3898899_carry_printout"
#         },
#         "type": "claimTopic",
#         "to": {
#           "label": "DocumentScrutiny",
#           "key": "documentscrutiny"
#         }
#       },
#       {
#         "from": {
#           "label": "Claim",
#           "key": "claim_3898899_carry_printout"
#         },
#         "type": "aboutCity",
#         "to": {
#           "label": "City",
#           "key": "city_marseille"
#         }
#       }
#     ]
#   },
#   "finish_reason": "🟢 complete",
#   "reason": "Extracted encounter in Marseille with document check for return ticket and general advice based on personal experience.",
#   "warnings": []
# }
# LLM finish_reason: 🟢 complete
# LLM reason: Extracted encounter in Marseille with document check for return ticket and general advice based on personal experience.
# Prepared 40 Cypher statements.
#
# Saved 40 statements to cypher_checkpoints/cypher_5.txt
# ✅ Executed 40 statements.
# {"post_id": 6281811, "post_url": "https://forum.awd.ru/viewtopic.php?p=6281811#p6281811", "author": "_ton4ik_", "date": "20 июл 2015, 17:56", "text": "Пересекали с девушкой французскую границу в Тулузе. Попросили показать обратный билет и подтверждение проживания.У нас были распечатки с букинга из кучи отелей, но не на все дни. Но пограничники в даты не вчитывались (а пограничников было двое). Просто пролистали, спросили как перемещаться будем, сказали, что интересный маршрут и пропустили. Надо уточнить, что мы в очереди были последними и может им просто хотелось пообщаться."}
# DeepSeek API latency: 135.50s
# 🟢 API finish_reason = stop
# {
#   "payload": {
#     "ontology_version": "pcfr_v3",
#     "nodes": [
#       {
#         "label": "City",
#         "key": "city_toulouse",
#         "properties": {
#           "entityName": "Toulouse"
#         }
#       },
#       {
#         "label": "Country",
#         "key": "country_france",
#         "properties": {
#           "entityName": "France"
#         }
#       },
#       {
#         "label": "Traveller",
#         "key": "traveller_author",
#         "properties": {
#           "entityName": "_ton4ik_"
#         }
#       },
#       {
#         "label": "Traveller",
#         "key": "traveller_girlfriend",
#         "properties": {
#           "entityName": "girlfriend"
#         }
#       },
#       {
#         "label": "BorderOfficer",
#         "key": "officer_toulouse",
#         "properties": {
#           "entityName": "Border officers in Toulouse"
#         }
#       },
#       {
#         "label": "Encounter",
#         "key": "encounter_6281811_author",
#         "properties": {
#           "pcfr:sourcePostID": 6281811,
#           "pcfr:sourcePostURL": "https://forum.awd.ru/viewtopic.php?p=6281811#p6281811",
#           "pcfr:sourcePostAuthor": "_ton4ik_",
#           "pcfr:sourcePostDateTime": "2015-07-20T17:56:00"
#         }
#       },
#       {
#         "label": "Encounter",
#         "key": "encounter_6281811_girlfriend",
#         "properties": {
#           "pcfr:sourcePostID": 6281811,
#           "pcfr:sourcePostURL": "https://forum.awd.ru/viewtopic.php?p=6281811#p6281811",
#           "pcfr:sourcePostAuthor": "_ton4ik_",
#           "pcfr:sourcePostDateTime": "2015-07-20T17:56:00"
#         }
#       },
#       {
#         "label": "DocumentCheck",
#         "key": "doccheck_encounter_6281811_author_returnticket",
#         "properties": {
#           "pcfr:presented": true
#         }
#       },
#       {
#         "label": "DocumentCheck",
#         "key": "doccheck_encounter_6281811_author_hotelbookingdoc",
#         "properties": {
#           "pcfr:presented": true
#         }
#       },
#       {
#         "label": "DocumentCheck",
#         "key": "doccheck_encounter_6281811_girlfriend_returnticket",
#         "properties": {
#           "pcfr:presented": true
#         }
#       },
#       {
#         "label": "DocumentCheck",
#         "key": "doccheck_encounter_6281811_girlfriend_hotelbookingdoc",
#         "properties": {
#           "pcfr:presented": true
#         }
#       },
#       {
#         "label": "Questioning",
#         "key": "questioning_encounter_6281811_author",
#         "properties": {
#           "pcfr:wasAsked": true,
#           "pcfr:topic": "how we will travel"
#         }
#       },
#       {
#         "label": "Questioning",
#         "key": "questioning_encounter_6281811_girlfriend",
#         "properties": {
#           "pcfr:wasAsked": true,
#           "pcfr:topic": "how we will travel"
#         }
#       },
#       {
#         "label": "Outcome",
#         "key": "outcome_encounter_6281811_author",
#         "properties": {
#           "pcfr:resultCode": "passed"
#         }
#       },
#       {
#         "label": "Outcome",
#         "key": "outcome_encounter_6281811_girlfriend",
#         "properties": {
#           "pcfr:resultCode": "passed"
#         }
#       },
#       {
#         "label": "ReturnTicket",
#         "key": "documenttype_returnticket",
#         "properties": {}
#       },
#       {
#         "label": "HotelBookingDoc",
#         "key": "documenttype_hotelbookingdoc",
#         "properties": {}
#       },
#       {
#         "label": "Printout",
#         "key": "evidenceformat_printout",
#         "properties": {}
#       },
#       {
#         "label": "PhysicalDocumentRequested",
#         "key": "checkmode_physicaldocumentrequested",
#         "properties": {}
#       },
#       {
#         "label": "Required",
#         "key": "requirementlevel_required",
#         "properties": {}
#       }
#     ],
#     "relationships": [
#       {
#         "from": {"label": "Encounter", "key": "encounter_6281811_author"},
#         "type": "pcfr:hasTraveler",
#         "to": {"label": "Traveller", "key": "traveller_author"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_6281811_girlfriend"},
#         "type": "pcfr:hasTraveler",
#         "to": {"label": "Traveller", "key": "traveller_girlfriend"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_6281811_author"},
#         "type": "pcfr:hasOfficer",
#         "to": {"label": "BorderOfficer", "key": "officer_toulouse"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_6281811_girlfriend"},
#         "type": "pcfr:hasOfficer",
#         "to": {"label": "BorderOfficer", "key": "officer_toulouse"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_6281811_author"},
#         "type": "pcfr:atCity",
#         "to": {"label": "City", "key": "city_toulouse"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_6281811_author"},
#         "type": "pcfr:atCountry",
#         "to": {"label": "Country", "key": "country_france"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_6281811_girlfriend"},
#         "type": "pcfr:atCity",
#         "to": {"label": "City", "key": "city_toulouse"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_6281811_girlfriend"},
#         "type": "pcfr:atCountry",
#         "to": {"label": "Country", "key": "country_france"}
#       },
#       {
#         "from": {"label": "City", "key": "city_toulouse"},
#         "type": "pcfr:locatedInCountry",
#         "to": {"label": "Country", "key": "country_france"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_6281811_author"},
#         "type": "pcfr:hasDocumentCheck",
#         "to": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_author_returnticket"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_6281811_author"},
#         "type": "pcfr:hasDocumentCheck",
#         "to": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_author_hotelbookingdoc"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_6281811_girlfriend"},
#         "type": "pcfr:hasDocumentCheck",
#         "to": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_girlfriend_returnticket"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_6281811_girlfriend"},
#         "type": "pcfr:hasDocumentCheck",
#         "to": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_girlfriend_hotelbookingdoc"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_author_returnticket"},
#         "type": "pcfr:requestedDocType",
#         "to": {"label": "ReturnTicket", "key": "documenttype_returnticket"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_author_hotelbookingdoc"},
#         "type": "pcfr:requestedDocType",
#         "to": {"label": "HotelBookingDoc", "key": "documenttype_hotelbookingdoc"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_girlfriend_returnticket"},
#         "type": "pcfr:requestedDocType",
#         "to": {"label": "ReturnTicket", "key": "documenttype_returnticket"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_girlfriend_hotelbookingdoc"},
#         "type": "pcfr:requestedDocType",
#         "to": {"label": "HotelBookingDoc", "key": "documenttype_hotelbookingdoc"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_author_returnticket"},
#         "type": "pcfr:presentedFormat",
#         "to": {"label": "Printout", "key": "evidenceformat_printout"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_author_hotelbookingdoc"},
#         "type": "pcfr:presentedFormat",
#         "to": {"label": "Printout", "key": "evidenceformat_printout"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_girlfriend_returnticket"},
#         "type": "pcfr:presentedFormat",
#         "to": {"label": "Printout", "key": "evidenceformat_printout"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_girlfriend_hotelbookingdoc"},
#         "type": "pcfr:presentedFormat",
#         "to": {"label": "Printout", "key": "evidenceformat_printout"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_author_returnticket"},
#         "type": "pcfr:checkMode",
#         "to": {"label": "PhysicalDocumentRequested", "key": "checkmode_physicaldocumentrequested"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_author_hotelbookingdoc"},
#         "type": "pcfr:checkMode",
#         "to": {"label": "PhysicalDocumentRequested", "key": "checkmode_physicaldocumentrequested"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_girlfriend_returnticket"},
#         "type": "pcfr:checkMode",
#         "to": {"label": "PhysicalDocumentRequested", "key": "checkmode_physicaldocumentrequested"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_girlfriend_hotelbookingdoc"},
#         "type": "pcfr:checkMode",
#         "to": {"label": "PhysicalDocumentRequested", "key": "checkmode_physicaldocumentrequested"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_author_returnticket"},
#         "type": "pcfr:treatedAsRequirementLevel",
#         "to": {"label": "Required", "key": "requirementlevel_required"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_author_hotelbookingdoc"},
#         "type": "pcfr:treatedAsRequirementLevel",
#         "to": {"label": "Required", "key": "requirementlevel_required"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_girlfriend_returnticket"},
#         "type": "pcfr:treatedAsRequirementLevel",
#         "to": {"label": "Required", "key": "requirementlevel_required"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_girlfriend_hotelbookingdoc"},
#         "type": "pcfr:treatedAsRequirementLevel",
#         "to": {"label": "Required", "key": "requirementlevel_required"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_author_returnticket"},
#         "type": "pcfr:checkedBy",
#         "to": {"label": "BorderOfficer", "key": "officer_toulouse"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_author_hotelbookingdoc"},
#         "type": "pcfr:checkedBy",
#         "to": {"label": "BorderOfficer", "key": "officer_toulouse"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_girlfriend_returnticket"},
#         "type": "pcfr:checkedBy",
#         "to": {"label": "BorderOfficer", "key": "officer_toulouse"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_6281811_girlfriend_hotelbookingdoc"},
#         "type": "pcfr:checkedBy",
#         "to": {"label": "BorderOfficer", "key": "officer_toulouse"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_6281811_author"},
#         "type": "pcfr:hasQuestioning",
#         "to": {"label": "Questioning", "key": "questioning_encounter_6281811_author"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_6281811_girlfriend"},
#         "type": "pcfr:hasQuestioning",
#         "to": {"label": "Questioning", "key": "questioning_encounter_6281811_girlfriend"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_6281811_author"},
#         "type": "pcfr:hasOutcome",
#         "to": {"label": "Outcome", "key": "outcome_encounter_6281811_author"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_6281811_girlfriend"},
#         "type": "pcfr:hasOutcome",
#         "to": {"label": "Outcome", "key": "outcome_encounter_6281811_girlfriend"}
#       }
#     ]
#   },
#   "finish_reason": "🟢 complete",
#   "reason": "Successfully extracted all entities and relationships from the text, including metadata for Encounters, with English translations where necessary.",
#   "warnings": []
# }
# LLM finish_reason: 🟢 complete
# LLM reason: Successfully extracted all entities and relationships from the text, including metadata for Encounters, with English translations where necessary.
# Prepared 70 Cypher statements.
#
# Saved 70 statements to cypher_checkpoints/cypher_6.txt
# ✅ Executed 70 statements.
# {"post_id": 7997540, "post_url": "https://forum.awd.ru/viewtopic.php?p=7997540#p7997540", "author": "chados", "date": "29 июн 2017, 21:11", "text": "Вернулись вчера, прилетали в SDG, паспортный контроль и багаж прошли за 25-30 минут, (знакомые говорят повезло так быстро). Инспектор спросила цель визита, сколько дней, подсунул бумагу с аирбнб и электронный билет (на нем текстовыделителем выделил нужные рейсы), глянула на билет и штампанула печать. Нас было 3 человека, после меня она наверное поняла что ребята со мной, их вообще не спрашивала ничего."}
# DeepSeek API latency: 226.84s
# 🟢 API finish_reason = stop
# {
#   "payload": {
#     "ontology_version": "v3",
#     "nodes": [
#       {
#         "label": "Traveller",
#         "key": "traveller_author",
#         "properties": {
#           "pcfr:entityName": "chados"
#         }
#       },
#       {
#         "label": "BorderOfficer",
#         "key": "officer_cdg_1",
#         "properties": {
#           "pcfr:entityName": "Inspector"
#         }
#       },
#       {
#         "label": "Airport",
#         "key": "airport_cdg",
#         "properties": {
#           "pcfr:entityName": "CDG"
#         }
#       },
#       {
#         "label": "City",
#         "key": "city_paris",
#         "properties": {
#           "pcfr:entityName": "Paris"
#         }
#       },
#       {
#         "label": "Country",
#         "key": "country_france",
#         "properties": {
#           "pcfr:entityName": "France"
#         }
#       },
#       {
#         "label": "Encounter",
#         "key": "encounter_7997540_author",
#         "properties": {
#           "pcfr:sourcePostID": 7997540,
#           "pcfr:sourcePostURL": "https://forum.awd.ru/viewtopic.php?p=7997540#p7997540",
#           "pcfr:sourcePostAuthor": "chados",
#           "pcfr:sourcePostDateTime": "2017-06-29T21:11:00",
#           "pcfr:encounterDurationSec": 1500
#         }
#       },
#       {
#         "label": "Questioning",
#         "key": "questioning_encounter_7997540_author",
#         "properties": {
#           "pcfr:wasAsked": true
#         }
#       },
#       {
#         "label": "VisitPurpose",
#         "key": "topic_visitpurpose",
#         "properties": {}
#       },
#       {
#         "label": "VisitDuration",
#         "key": "topic_visitduration",
#         "properties": {}
#       },
#       {
#         "label": "DocumentCheck",
#         "key": "doccheck_encounter_7997540_author_hotelbooking",
#         "properties": {
#           "pcfr:presented": true
#         }
#       },
#       {
#         "label": "DocumentCheck",
#         "key": "doccheck_encounter_7997540_author_returnticket",
#         "properties": {
#           "pcfr:presented": true
#         }
#       },
#       {
#         "label": "Printout",
#         "key": "format_printout",
#         "properties": {}
#       },
#       {
#         "label": "PhysicalDocumentRequested",
#         "key": "mode_physicaldocumentrequested",
#         "properties": {}
#       },
#       {
#         "label": "HotelBookingDoc",
#         "key": "doctype_hotelbookingdoc",
#         "properties": {}
#       },
#       {
#         "label": "ReturnTicket",
#         "key": "doctype_returnticket",
#         "properties": {}
#       },
#       {
#         "label": "Stamping",
#         "key": "stamping_encounter_7997540_author",
#         "properties": {}
#       },
#       {
#         "label": "ForeignPassport",
#         "key": "doctype_foreignpassport",
#         "properties": {}
#       },
#       {
#         "label": "Outcome",
#         "key": "outcome_encounter_7997540_author",
#         "properties": {
#           "pcfr:resultCode": "stamped"
#         }
#       },
#       {
#         "label": "Claim",
#         "key": "claim_7997540_speed",
#         "properties": {
#           "pcfr:sourcePostID": 7997540,
#           "pcfr:sourcePostURL": "https://forum.awd.ru/viewtopic.php?p=7997540#p7997540",
#           "pcfr:sourcePostAuthor": "chados",
#           "pcfr:sourcePostDateTime": "2017-06-29T21:11:00",
#           "pcfr:claimText": "Acquaintances say it was lucky to be so fast."
#         }
#       },
#       {
#         "label": "GeneralKnowledge",
#         "key": "assertionkind_generalknowledge",
#         "properties": {}
#       },
#       {
#         "label": "Heard",
#         "key": "evidentiality_heard",
#         "properties": {}
#       },
#       {
#         "label": "SingleEventScope",
#         "key": "scope_singleeventscope",
#         "properties": {}
#       },
#       {
#         "label": "ProcessingSpeed",
#         "key": "topic_processingspeed",
#         "properties": {}
#       }
#     ],
#     "relationships": [
#       {
#         "from": { "label": "Encounter", "key": "encounter_7997540_author" },
#         "type": "pcfr:hasTraveler",
#         "to": { "label": "Traveller", "key": "traveller_author" }
#       },
#       {
#         "from": { "label": "Encounter", "key": "encounter_7997540_author" },
#         "type": "pcfr:hasOfficer",
#         "to": { "label": "BorderOfficer", "key": "officer_cdg_1" }
#       },
#       {
#         "from": { "label": "Encounter", "key": "encounter_7997540_author" },
#         "type": "pcfr:hasDocumentCheck",
#         "to": { "label": "DocumentCheck", "key": "doccheck_encounter_7997540_author_hotelbooking" }
#       },
#       {
#         "from": { "label": "Encounter", "key": "encounter_7997540_author" },
#         "type": "pcfr:hasDocumentCheck",
#         "to": { "label": "DocumentCheck", "key": "doccheck_encounter_7997540_author_returnticket" }
#       },
#       {
#         "from": { "label": "Encounter", "key": "encounter_7997540_author" },
#         "type": "pcfr:hasQuestioning",
#         "to": { "label": "Questioning", "key": "questioning_encounter_7997540_author" }
#       },
#       {
#         "from": { "label": "Encounter", "key": "encounter_7997540_author" },
#         "type": "pcfr:hasStamping",
#         "to": { "label": "Stamping", "key": "stamping_encounter_7997540_author" }
#       },
#       {
#         "from": { "label": "Encounter", "key": "encounter_7997540_author" },
#         "type": "pcfr:hasOutcome",
#         "to": { "label": "Outcome", "key": "outcome_encounter_7997540_author" }
#       },
#       {
#         "from": { "label": "Encounter", "key": "encounter_7997540_author" },
#         "type": "pcfr:atAirport",
#         "to": { "label": "Airport", "key": "airport_cdg" }
#       },
#       {
#         "from": { "label": "Encounter", "key": "encounter_7997540_author" },
#         "type": "pcfr:atCity",
#         "to": { "label": "City", "key": "city_paris" }
#       },
#       {
#         "from": { "label": "Encounter", "key": "encounter_7997540_author" },
#         "type": "pcfr:atCountry",
#         "to": { "label": "Country", "key": "country_france" }
#       },
#       {
#         "from": { "label": "Airport", "key": "airport_cdg" },
#         "type": "pcfr:locatedInCity",
#         "to": { "label": "City", "key": "city_paris" }
#       },
#       {
#         "from": { "label": "City", "key": "city_paris" },
#         "type": "pcfr:locatedInCountry",
#         "to": { "label": "Country", "key": "country_france" }
#       },
#       {
#         "from": { "label": "Questioning", "key": "questioning_encounter_7997540_author" },
#         "type": "pcfr:questionTopic",
#         "to": { "label": "VisitPurpose", "key": "topic_visitpurpose" }
#       },
#       {
#         "from": { "label": "Questioning", "key": "questioning_encounter_7997540_author" },
#         "type": "pcfr:questionTopic",
#         "to": { "label": "VisitDuration", "key": "topic_visitduration" }
#       },
#       {
#         "from": { "label": "DocumentCheck", "key": "doccheck_encounter_7997540_author_hotelbooking" },
#         "type": "pcfr:requestedDocType",
#         "to": { "label": "HotelBookingDoc", "key": "doctype_hotelbookingdoc" }
#       },
#       {
#         "from": { "label": "DocumentCheck", "key": "doccheck_encounter_7997540_author_hotelbooking" },
#         "type": "pcfr:presentedFormat",
#         "to": { "label": "Printout", "key": "format_printout" }
#       },
#       {
#         "from": { "label": "DocumentCheck", "key": "doccheck_encounter_7997540_author_hotelbooking" },
#         "type": "pcfr:checkMode",
#         "to": { "label": "PhysicalDocumentRequested", "key": "mode_physicaldocumentrequested" }
#       },
#       {
#         "from": { "label": "DocumentCheck", "key": "doccheck_encounter_7997540_author_hotelbooking" },
#         "type": "pcfr:checkedBy",
#         "to": { "label": "BorderOfficer", "key": "officer_cdg_1" }
#       },
#       {
#         "from": { "label": "DocumentCheck", "key": "doccheck_encounter_7997540_author_returnticket" },
#         "type": "pcfr:requestedDocType",
#         "to": { "label": "ReturnTicket", "key": "doctype_returnticket" }
#       },
#       {
#         "from": { "label": "DocumentCheck", "key": "doccheck_encounter_7997540_author_returnticket" },
#         "type": "pcfr:presentedFormat",
#         "to": { "label": "Printout", "key": "format_printout" }
#       },
#       {
#         "from": { "label": "DocumentCheck", "key": "doccheck_encounter_7997540_author_returnticket" },
#         "type": "pcfr:checkMode",
#         "to": { "label": "PhysicalDocumentRequested", "key": "mode_physicaldocumentrequested" }
#       },
#       {
#         "from": { "label": "DocumentCheck", "key": "doccheck_encounter_7997540_author_returnticket" },
#         "type": "pcfr:checkedBy",
#         "to": { "label": "BorderOfficer", "key": "officer_cdg_1" }
#       },
#       {
#         "from": { "label": "Stamping", "key": "stamping_encounter_7997540_author" },
#         "type": "pcfr:stampsDocument",
#         "to": { "label": "ForeignPassport", "key": "doctype_foreignpassport" }
#       },
#       {
#         "from": { "label": "Stamping", "key": "stamping_encounter_7997540_author" },
#         "type": "pcfr:issuedBy",
#         "to": { "label": "BorderOfficer", "key": "officer_cdg_1" }
#       },
#       {
#         "from": { "label": "Claim", "key": "claim_7997540_speed" },
#         "type": "pcfr:assertionKind",
#         "to": { "label": "GeneralKnowledge", "key": "assertionkind_generalknowledge" }
#       },
#       {
#         "from": { "label": "Claim", "key": "claim_7997540_speed" },
#         "type": "pcfr:evidentiality",
#         "to": { "label": "Heard", "key": "evidentiality_heard" }
#       },
#       {
#         "from": { "label": "Claim", "key": "claim_7997540_speed" },
#         "type": "pcfr:claimScope",
#         "to": { "label": "SingleEventScope", "key": "scope_singleeventscope" }
#       },
#       {
#         "from": { "label": "Claim", "key": "claim_7997540_speed" },
#         "type": "pcfr:claimTopic",
#         "to": { "label": "ProcessingSpeed", "key": "topic_processingspeed" }
#       },
#       {
#         "from": { "label": "Claim", "key": "claim_7997540_speed" },
#         "type": "pcfr:aboutAirport",
#         "to": { "label": "Airport", "key": "airport_cdg" }
#       }
#     ]
#   },
#   "finish_reason": "🟢 complete",
#   "reason": "Extracted all explicit facts from the post text, including encounter details, questioning, document checks, stamping, outcome, and a claim about speed.",
#   "warnings": ["Duration converted from range 25-30 minutes to 1500 seconds using lower bound.", "SDG transliterated to CDG (Charles de Gaulle Airport) for English consistency."]
# }
# LLM finish_reason: 🟢 complete
# LLM reason: Extracted all explicit facts from the post text, including encounter details, questioning, document checks, stamping, outcome, and a claim about speed.
# Prepared 74 Cypher statements.
#
# Saved 74 statements to cypher_checkpoints/cypher_7.txt
# ✅ Executed 74 statements.
# {"post_id": 8694300, "post_url": "https://forum.awd.ru/viewtopic.php?p=8694300#p8694300", "author": "murz44", "date": "24 май 2018, 17:01", "text": "Летел в Лион с пересадкой во Франфурте. В Лионе был паспортный контроль для всех. Я рта не успел раскрыть, как молодая башня влепила мне еще одну въездную печать туда где у меня выездные штампы даже не открыв страницу с визой. Такой вот контроль."}
# DeepSeek API latency: 137.80s
# 🟢 API finish_reason = stop
# {
#   "payload": {
#     "ontology_version": "pcfr_v3",
#     "nodes": [
#       {
#         "label": "Traveller",
#         "key": "traveller_murz44",
#         "properties": {
#           "pcfr:entityName": "murz44"
#         }
#       },
#       {
#         "label": "BorderOfficer",
#         "key": "officer_young_lyon",
#         "properties": {
#           "pcfr:entityName": "young officer"
#         }
#       },
#       {
#         "label": "City",
#         "key": "city_lyon",
#         "properties": {
#           "pcfr:entityName": "Lyon"
#         }
#       },
#       {
#         "label": "Country",
#         "key": "country_france",
#         "properties": {
#           "pcfr:entityName": "France"
#         }
#       },
#       {
#         "label": "Airport",
#         "key": "airport_lys",
#         "properties": {
#           "pcfr:entityName": "Lyon Airport"
#         }
#       },
#       {
#         "label": "Encounter",
#         "key": "encounter_8694300_murz44",
#         "properties": {
#           "pcfr:sourcePostID": 8694300,
#           "pcfr:sourcePostURL": "https://forum.awd.ru/viewtopic.php?p=8694300#p8694300",
#           "pcfr:sourcePostAuthor": "murz44",
#           "pcfr:sourcePostDateTime": "2018-05-24T17:01:00"
#         }
#       },
#       {
#         "label": "Stamping",
#         "key": "stamping_encounter_8694300_murz44",
#         "properties": {}
#       },
#       {
#         "label": "Outcome",
#         "key": "outcome_encounter_8694300_murz44",
#         "properties": {}
#       },
#       {
#         "label": "DocumentCheck",
#         "key": "doccheck_encounter_8694300_murz44_passport",
#         "properties": {
#           "pcfr:presented": true
#         }
#       },
#       {
#         "label": "PassportWithVisa",
#         "key": "doctype_passportwithvisa",
#         "properties": {}
#       },
#       {
#         "label": "NoExtraProcedures",
#         "key": "screeningstatus_noextra",
#         "properties": {}
#       }
#     ],
#     "relationships": [
#       {
#         "from": { "label": "Encounter", "key": "encounter_8694300_murz44" },
#         "type": "pcfr:hasTraveler",
#         "to": { "label": "Traveller", "key": "traveller_murz44" }
#       },
#       {
#         "from": { "label": "Encounter", "key": "encounter_8694300_murz44" },
#         "type": "pcfr:hasOfficer",
#         "to": { "label": "BorderOfficer", "key": "officer_young_lyon" }
#       },
#       {
#         "from": { "label": "Encounter", "key": "encounter_8694300_murz44" },
#         "type": "pcfr:atAirport",
#         "to": { "label": "Airport", "key": "airport_lys" }
#       },
#       {
#         "from": { "label": "Encounter", "key": "encounter_8694300_murz44" },
#         "type": "pcfr:atCity",
#         "to": { "label": "City", "key": "city_lyon" }
#       },
#       {
#         "from": { "label": "Encounter", "key": "encounter_8694300_murz44" },
#         "type": "pcfr:atCountry",
#         "to": { "label": "Country", "key": "country_france" }
#       },
#       {
#         "from": { "label": "Encounter", "key": "encounter_8694300_murz44" },
#         "type": "pcfr:hasStamping",
#         "to": { "label": "Stamping", "key": "stamping_encounter_8694300_murz44" }
#       },
#       {
#         "from": { "label": "Encounter", "key": "encounter_8694300_murz44" },
#         "type": "pcfr:hasOutcome",
#         "to": { "label": "Outcome", "key": "outcome_encounter_8694300_murz44" }
#       },
#       {
#         "from": { "label": "Encounter", "key": "encounter_8694300_murz44" },
#         "type": "pcfr:hasDocumentCheck",
#         "to": { "label": "DocumentCheck", "key": "doccheck_encounter_8694300_murz44_passport" }
#       },
#       {
#         "from": { "label": "Encounter", "key": "encounter_8694300_murz44" },
#         "type": "pcfr:hasScreeningStatus",
#         "to": { "label": "NoExtraProcedures", "key": "screeningstatus_noextra" }
#       },
#       {
#         "from": { "label": "Stamping", "key": "stamping_encounter_8694300_murz44" },
#         "type": "pcfr:stampsDocument",
#         "to": { "label": "PassportWithVisa", "key": "doctype_passportwithvisa" }
#       },
#       {
#         "from": { "label": "Stamping", "key": "stamping_encounter_8694300_murz44" },
#         "type": "pcfr:issuedBy",
#         "to": { "label": "BorderOfficer", "key": "officer_young_lyon" }
#       },
#       {
#         "from": { "label": "DocumentCheck", "key": "doccheck_encounter_8694300_murz44_passport" },
#         "type": "pcfr:requestedDocType",
#         "to": { "label": "PassportWithVisa", "key": "doctype_passportwithvisa" }
#       },
#       {
#         "from": { "label": "DocumentCheck", "key": "doccheck_encounter_8694300_murz44_passport" },
#         "type": "pcfr:checkedBy",
#         "to": { "label": "BorderOfficer", "key": "officer_young_lyon" }
#       },
#       {
#         "from": { "label": "Airport", "key": "airport_lys" },
#         "type": "pcfr:locatedInCity",
#         "to": { "label": "City", "key": "city_lyon" }
#       },
#       {
#         "from": { "label": "City", "key": "city_lyon" },
#         "type": "pcfr:locatedInCountry",
#         "to": { "label": "Country", "key": "country_france" }
#       }
#     ]
#   },
#   "finish_reason": "🟢 complete",
#   "reason": "All facts extracted from text, including traveller, officer, location, encounter, stamping, document check, and outcome.",
#   "warnings": []
# }
# LLM finish_reason: 🟢 complete
# LLM reason: All facts extracted from text, including traveller, officer, location, encounter, stamping, document check, and outcome.
# Prepared 37 Cypher statements.
#
# Saved 37 statements to cypher_checkpoints/cypher_8.txt
# ✅ Executed 37 statements.
# {"post_id": 11719467, "post_url": "https://forum.awd.ru/viewtopic.php?p=11719467#p11719467", "author": "Ninio", "date": "05 фев 2024, 11:26", "text": "11 января - Стамбул-Париж.В Стамбуле ничего не спрашивали.В Париже (ШДГ) Терминал 1 - при мне всех спрашивали, когда улетаете обратно, где будете жить. Но ни у меня, ни у тех, кого я видела, не смотрели подтверждение.Вопрос - ответ - штамп."}
# DeepSeek API latency: 262.59s
# 🟢 API finish_reason = stop
# {
#   "payload": {
#     "ontology_version": "pcfr-v3",
#     "nodes": [
#       {
#         "label": "Traveller",
#         "key": "traveller_ninio",
#         "properties": {
#           "pcfr:entityName": "Ninio"
#         }
#       },
#       {
#         "label": "City",
#         "key": "city_istanbul",
#         "properties": {
#           "pcfr:entityName": "Istanbul"
#         }
#       },
#       {
#         "label": "Country",
#         "key": "country_turkey",
#         "properties": {
#           "pcfr:entityName": "Turkey"
#         }
#       },
#       {
#         "label": "City",
#         "key": "city_paris",
#         "properties": {
#           "pcfr:entityName": "Paris"
#         }
#       },
#       {
#         "label": "Country",
# ...
#           "key": "encounter_11888385_author_1"
#         },
#         "type": "pcfr:atCountry",
#         "to": {
#           "label": "Country",
#           "key": "country_france"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11888385_author_1"
#         },
#         "type": "pcfr:hasStamping",
#         "to": {
#           "label": "Stamping",
#           "key": "stamping_encounter_11888385_author_1"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11888385_author_1"
#         },
#         "type": "pcfr:hasOutcome",
#         "to": {
#           "label": "Outcome",
#           "key": "outcome_encounter_11888385_author_1"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11888385_author_2"
#         },
#         "type": "pcfr:hasTraveler",
#         "to": {
#           "label": "Traveller",
#           "key": "traveller_author"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11888385_author_2"
#         },
#         "type": "pcfr:hasOfficer",
#         "to": {
#           "label": "BorderOfficer",
#           "key": "officer_11888385_1"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11888385_author_2"
#         },
#         "type": "pcfr:atAirport",
#         "to": {
#           "label": "Airport",
#           "key": "airport_cdg"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11888385_author_2"
#         },
#         "type": "pcfr:atCity",
#         "to": {
#           "label": "City",
#           "key": "city_paris"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11888385_author_2"
#         },
#         "type": "pcfr:atCountry",
#         "to": {
#           "label": "Country",
#           "key": "country_france"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11888385_author_2"
#         },
#         "type": "pcfr:hasDocumentCheck",
#         "to": {
#           "label": "DocumentCheck",
#           "key": "doccheck_encounter_11888385_author_2_hotelbooking"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11888385_author_2"
#         },
#         "type": "pcfr:hasDocumentCheck",
#         "to": {
#           "label": "DocumentCheck",
#           "key": "doccheck_encounter_11888385_author_2_cash"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11888385_author_2"
#         },
#         "type": "pcfr:hasDocumentCheck",
#         "to": {
#           "label": "DocumentCheck",
#           "key": "doccheck_encounter_11888385_author_2_paymentcard"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11888385_author_2"
#         },
#         "type": "pcfr:hasQuestioning",
#         "to": {
#           "label": "Questioning",
#           "key": "questioning_encounter_11888385_author_2"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11888385_author_2"
#         },
#         "type": "pcfr:hasStamping",
#         "to": {
#           "label": "Stamping",
#           "key": "stamping_encounter_11888385_author_2"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11888385_author_2"
#         },
#         "type": "pcfr:hasOutcome",
#         "to": {
#           "label": "Outcome",
#           "key": "outcome_encounter_11888385_author_2"
#         }
#       },
#       {
#         "from": {
#           "label": "DocumentCheck",
#           "key": "doccheck_encounter_11888385_author_2_hotelbooking"
#         },
#         "type": "pcfr:requestedDocType",
#         "to": {
#           "label": "HotelBookingDoc",
#           "key": "HotelBookingDoc"
#         }
#       },
#       {
#         "from": {
#           "label": "DocumentCheck",
#           "key": "doccheck_encounter_11888385_author_2_cash"
#         },
#         "type": "pcfr:requestedDocType",
#         "to": {
#           "label": "Cash",
#           "key": "Cash"
#         }
#       },
#       {
#         "from": {
#           "label": "DocumentCheck",
#           "key": "doccheck_encounter_11888385_author_2_paymentcard"
#         },
#         "type": "pcfr:requestedDocType",
#         "to": {
#           "label": "PaymentCard",
#           "key": "PaymentCard"
#         }
#       },
#       {
#         "from": {
#           "label": "Questioning",
#           "key": "questioning_encounter_11888385_author_2"
#         },
#         "type": "pcfr:questionTopic",
#         "to": {
#           "label": "VisitPurpose",
#           "key": "VisitPurpose"
#         }
#       },
#       {
#         "from": {
#           "label": "Questioning",
#           "key": "questioning_encounter_11888385_author_2"
#         },
#         "type": "pcfr:questionTopic",
#         "to": {
#           "label": "VisitDuration",
#           "key": "VisitDuration"
#         }
#       },
#       {
#         "from": {
#           "label": "Questioning",
#           "key": "questioning_encounter_11888385_author_2"
#         },
#         "type": "pcfr:questionTopic",
#         "to": {
#           "label": "HotelPaymentStatus",
#           "key": "HotelPaymentStatus"
#         }
#       },
#       {
#         "from": {
#           "label": "Questioning",
#           "key": "questioning_encounter_11888385_author_2"
#         },
#         "type": "pcfr:questionTopic",
#         "to": {
#           "label": "CashAmount",
#           "key": "CashAmount"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11888385_friend"
#         },
#         "type": "pcfr:hasTraveler",
#         "to": {
#           "label": "Traveller",
#           "key": "traveller_friend"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11888385_friend"
#         },
#         "type": "pcfr:hasOfficer",
#         "to": {
#           "label": "BorderOfficer",
#           "key": "officer_11888385_2"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11888385_friend"
#         },
#         "type": "pcfr:atAirport",
#         "to": {
#           "label": "Airport",
#           "key": "airport_cdg"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11888385_friend"
#         },
#         "type": "pcfr:atCity",
#         "to": {
#           "label": "City",
#           "key": "city_paris"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11888385_friend"
#         },
#         "type": "pcfr:atCountry",
#         "to": {
#           "label": "Country",
#           "key": "country_france"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11888385_friend"
#         },
#         "type": "pcfr:hasStamping",
#         "to": {
#           "label": "Stamping",
#           "key": "stamping_encounter_11888385_friend"
#         }
#       },
#       {
#         "from": {
#           "label": "Encounter",
#           "key": "encounter_11888385_friend"
#         },
#         "type": "pcfr:hasOutcome",
#         "to": {
#           "label": "Outcome",
#           "key": "outcome_encounter_11888385_friend"
#         }
#       }
#     ]
#   },
#   "finish_reason": "🟢 complete",
#   "reason": "Extracted all encounters, document checks, questioning, stamping, outcomes, officers, and one claim from the text.",
#   "warnings": []
# }
# LLM finish_reason: 🟢 complete
# LLM reason: Extracted all encounters, document checks, questioning, stamping, outcomes, officers, and one claim from the text.
# Prepared 65 Cypher statements.
#
# Saved 65 statements to cypher_checkpoints/cypher_10.txt
# ✅ Executed 65 statements.
# {"post_id": 10918979, "post_url": "https://forum.awd.ru/viewtopic.php?p=10918979#p10918979", "author": "Melkaya13", "date": "12 май 2022, 22:54", "text": "Летала в апреле во Францию по однократной эстонской визе под поездку. Страной въезда была Франция - выезда Эстония. При посадке на рейс очень строго попросили показать обратный билет. На паспортном контроле в Шарль де Голь попросили рассказать где я буду проживать во Франции и показать бронь отеля. Поэтому на всякий случай держите при себе распечатки."}
# DeepSeek API latency: 201.44s
# 🟢 API finish_reason = stop
# {
#   "payload": {
#     "ontology_version": "pcfr_v3",
#     "nodes": [
#       {
#         "label": "Traveller",
#         "key": "traveller_melkaya13",
#         "properties": {
#           "pcfr:entityName": "Melkaya13"
#         }
#       },
#       {
#         "label": "Airport",
#         "key": "airport_cdg",
#         "properties": {
#           "pcfr:entityName": "Charles de Gaulle Airport"
#         }
#       },
#       {
#         "label": "Country",
#         "key": "country_france",
#         "properties": {
#           "pcfr:entityName": "France"
#         }
#       },
#       {
#         "label": "Country",
#         "key": "country_estonia",
#         "properties": {
#           "pcfr:entityName": "Estonia"
#         }
#       },
#       {
#         "label": "Encounter",
#         "key": "encounter_10918979_melkaya13",
#         "properties": {
#           "pcfr:sourcePostID": 10918979,
#           "pcfr:sourcePostURL": "https://forum.awd.ru/viewtopic.php?p=10918979#p10918979",
#           "pcfr:sourcePostAuthor": "Melkaya13",
#           "pcfr:sourcePostDateTime": "2022-05-12T22:54:00"
#         }
#       },
#       {
#         "label": "DocumentCheck",
#         "key": "doccheck_encounter_10918979_melkaya13_hotelbooking",
#         "properties": {
#           "pcfr:presented": true
#         }
#       },
#       {
#         "label": "HotelBookingDoc",
#         "key": "hotelbookingdoc",
#         "properties": {}
#       },
#       {
#         "label": "PhysicalDocumentRequested",
#         "key": "physicaldocumentrequested",
#         "properties": {}
#       },
#       {
#         "label": "Required",
#         "key": "required",
#         "properties": {}
#       },
#       {
#         "label": "Questioning",
#         "key": "questioning_encounter_10918979_melkaya13",
#         "properties": {
#           "pcfr:wasAsked": true
#         }
#       },
#       {
#         "label": "VisitPurpose",
#         "key": "visitpurpose",
#         "properties": {}
#       },
#       {
#         "label": "Claim",
#         "key": "claim_10918979_returnticket",
#         "properties": {
#           "pcfr:sourcePostID": 10918979,
#           "pcfr:sourcePostURL": "https://forum.awd.ru/viewtopic.php?p=10918979#p10918979",
#           "pcfr:sourcePostAuthor": "Melkaya13",
#           "pcfr:sourcePostDateTime": "2022-05-12T22:54:00",
#           "pcfr:claimText": "During boarding, return ticket was strictly requested."
#         }
#       },
#       {
#         "label": "FirstPersonExperience",
#         "key": "firstpersonexperience",
#         "properties": {}
#       },
#       {
#         "label": "Experienced",
#         "key": "experienced",
#         "properties": {}
#       },
#       {
#         "label": "SingleEventScope",
#         "key": "singleventscope",
#         "properties": {}
#       },
#       {
#         "label": "DocumentScrutiny",
#         "key": "documentscrutiny",
#         "properties": {}
#       },
#       {
#         "label": "Claim",
#         "key": "claim_10918979_printouts",
#         "properties": {
#           "pcfr:sourcePostID": 10918979,
#           "pcfr:sourcePostURL": "https://forum.awd.ru/viewtopic.php?p=10918979#p10918979",
#           "pcfr:sourcePostAuthor": "Melkaya13",
#           "pcfr:sourcePostDateTime": "2022-05-12T22:54:00",
#           "pcfr:claimText": "Keep printouts with you just in case."
#         }
#       },
#       {
#         "label": "Advice",
#         "key": "advice",
#         "properties": {}
#       },
#       {
#         "label": "Inferred",
#         "key": "inferred",
#         "properties": {}
#       },
#       {
#         "label": "UniversalScope",
#         "key": "universalscope",
#         "properties": {}
#       }
#     ],
#     "relationships": [
#       {
#         "from": {"label": "Encounter", "key": "encounter_10918979_melkaya13"},
#         "type": "pcfr:hasTraveler",
#         "to": {"label": "Traveller", "key": "traveller_melkaya13"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_10918979_melkaya13"},
#         "type": "pcfr:atAirport",
#         "to": {"label": "Airport", "key": "airport_cdg"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_10918979_melkaya13"},
#         "type": "pcfr:atCountry",
#         "to": {"label": "Country", "key": "country_france"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_10918979_melkaya13"},
#         "type": "pcfr:hasDocumentCheck",
#         "to": {"label": "DocumentCheck", "key": "doccheck_encounter_10918979_melkaya13_hotelbooking"}
#       },
#       {
#         "from": {"label": "Encounter", "key": "encounter_10918979_melkaya13"},
#         "type": "pcfr:hasQuestioning",
#         "to": {"label": "Questioning", "key": "questioning_encounter_10918979_melkaya13"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_10918979_melkaya13_hotelbooking"},
#         "type": "pcfr:requestedDocType",
#         "to": {"label": "HotelBookingDoc", "key": "hotelbookingdoc"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_10918979_melkaya13_hotelbooking"},
#         "type": "pcfr:checkMode",
#         "to": {"label": "PhysicalDocumentRequested", "key": "physicaldocumentrequested"}
#       },
#       {
#         "from": {"label": "DocumentCheck", "key": "doccheck_encounter_10918979_melkaya13_hotelbooking"},
#         "type": "pcfr:treatedAsRequirementLevel",
#         "to": {"label": "Required", "key": "required"}
#       },
#       {
#         "from": {"label": "Questioning", "key": "questioning_encounter_10918979_melkaya13"},
#         "type": "pcfr:questionTopic",
#         "to": {"label": "VisitPurpose", "key": "visitpurpose"}
#       },
#       {
#         "from": {"label": "Claim", "key": "claim_10918979_returnticket"},
#         "type": "pcfr:assertionKind",
#         "to": {"label": "FirstPersonExperience", "key": "firstpersonexperience"}
#       },
#       {
#         "from": {"label": "Claim", "key": "claim_10918979_returnticket"},
#         "type": "pcfr:evidentiality",
#         "to": {"label": "Experienced", "key": "experienced"}
#       },
#       {
#         "from": {"label": "Claim", "key": "claim_10918979_returnticket"},
#         "type": "pcfr:claimScope",
#         "to": {"label": "SingleEventScope", "key": "singleventscope"}
#       },
#       {
#         "from": {"label": "Claim", "key": "claim_10918979_returnticket"},
#         "type": "pcfr:claimTopic",
#         "to": {"label": "DocumentScrutiny", "key": "documentscrutiny"}
#       },
#       {
#         "from": {"label": "Claim", "key": "claim_10918979_printouts"},
#         "type": "pcfr:assertionKind",
#         "to": {"label": "Advice", "key": "advice"}
#       },
#       {
#         "from": {"label": "Claim", "key": "claim_10918979_printouts"},
#         "type": "pcfr:evidentiality",
#         "to": {"label": "Inferred", "key": "inferred"}
#       },
#       {
#         "from": {"label": "Claim", "key": "claim_10918979_printouts"},
#         "type": "pcfr:claimScope",
#         "to": {"label": "UniversalScope", "key": "universalscope"}
#       },
#       {
#         "from": {"label": "Claim", "key": "claim_10918979_printouts"},
#         "type": "pcfr:claimTopic",
#         "to": {"label": "DocumentScrutiny", "key": "documentscrutiny"}
#       }
#     ]
#   },
#   "finish_reason": "🟢 complete",
#   "reason": "Extracted all relevant facts from the post text, including encounter, document checks, questioning, and claims.",
#   "warnings": []
# }
# LLM finish_reason: 🟢 complete
# LLM reason: Extracted all relevant facts from the post text, including encounter, document checks, questioning, and claims.
# Prepared 55 Cypher statements.
#
# Saved 55 statements to cypher_checkpoints/cypher_11.txt
# ✅ Executed 55 statements.
# CompletedProcess(args=['afplay', '/System/Library/Sounds/Blow.aiff'], returncode=0)

# %%
было 93 104 97 113 для ШДГ и 25 23 для малого

# %%
# 8 RAG

# %%
def rag_answer(user_query: str) -> None:
    from neo4j import GraphDatabase
    import os
    import requests

    URI = "neo4j://localhost:7688"
    USER = "neo4j"
    PASSWORD = "12345678"
    DATABASE = "neo4j"

    driver = GraphDatabase.driver(URI, auth=(USER, PASSWORD))

    try:
        with driver.session(database=DATABASE) as session:
            cypher = """
            MATCH (n)
            WHERE any(k IN keys(n) WHERE toString(n[k]) CONTAINS $q)
            RETURN n
            LIMIT 20
            """
            records = session.run(cypher, q=user_query).data()
    finally:
        driver.close()

    # Build minimal context
    context_lines = []
    for r in records:
        n = r.get("n")
        if n is None:
            continue
        labels = list(n.labels) if hasattr(n, "labels") else []
        props = dict(n)
        context_lines.append(f"labels={labels}; props={props}")

    context = "\n".join(context_lines) if context_lines else "NO_MATCHES"

    DEEPSEEK_API_KEY = "sk-8da8031877dc4c39ae8d7b624c70f01f"
    if not DEEPSEEK_API_KEY:
        raise RuntimeError("Set env var DEEPSEEK_API_KEY first.")

    DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL", "https://api.deepseek.com").rstrip("/")
    MODEL = os.getenv("DEEPSEEK_MODEL", "deepseek-chat")

    prompt = (
        "You are a concise assistant. Use ONLY the provided context to answer. "
        "If the answer is not in context, say you do not know.\n\n"
        f"Context:\n{context}\n\n"
        f"Question: {user_query}\n"
        "Answer:"
    )

    url = f"{DEEPSEEK_BASE_URL}/v1/chat/completions"
    headers = {
        "Authorization": f"Bearer {DEEPSEEK_API_KEY}",
        "Content-Type": "application/json",
    }

    payload = {
        "model": MODEL,
        "messages": [
            {"role": "system", "content": "Answer succinctly and only from context."},
            {"role": "user", "content": prompt},
        ],
        "temperature": 0.2,
    }

    resp = requests.post(url, headers=headers, json=payload, timeout=180)
    resp.raise_for_status()
    data = resp.json()

    content = data["choices"][0]["message"]["content"]
    print(content)

# %%
# 9 Проверка RAG

# %%
rag_answer('Является ли паспортный контроль в Париже строгим?')
# Out:
# Я не знаю.

# %%
# ??? Запись в базу уже из файла с диска

# %%
from __future__ import annotations
from pathlib import Path
from typing import Optional, Iterable
from neo4j import GraphDatabase


def _split_cypher_statements(text: str) -> list[str]:
    """
    Split on semicolons, ignoring empty chunks.
    (Assumes your generator doesn't put ';' inside string literals.)
    """
    parts = [p.strip() for p in text.split(";")]
    return [p for p in parts if p]


def run_cypher_file(
    cypher_path: str,
    uri: str = "neo4j://localhost:7688",
    user: str = "neo4j",
    password: str = "12345678",
    database: Optional[str] = None,
) -> None:
    """
    Reads Cypher statements from a file and executes them sequentially.
    Each statement is run as its own query (Neo4j requires 1 statement per run()).
    """
    path = Path(cypher_path)
    if not path.exists():
        raise FileNotFoundError(f"Cypher file not found: {path}")

    cypher_text = path.read_text(encoding="utf-8")
    statements = _split_cypher_statements(cypher_text)

    if not statements:
        print("No Cypher statements found in file.")
        return

    driver = GraphDatabase.driver(uri, auth=(user, password))
    try:
        with driver.session(database=database) as session:
            for i, stmt in enumerate(statements, start=1):
                session.run(stmt).consume()  # consume forces execution now
                # print(f"✅ {i}/{len(statements)} executed")
        print(f"✅ Executed {len(statements)} statements from {path.name}")
    finally:
        driver.close()

run_cypher_file("cypher_checkpoints/cypher_1.txt", uri="neo4j://localhost:7688", user="neo4j", password="12345678")
# Out:
# ✅ Executed 113 statements from cypher_1.txt
